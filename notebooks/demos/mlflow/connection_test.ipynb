# %%
from mlflow import MlflowClient

from mlflow_utils import load_config as load_ml_config
from mlflow_utils import test_server_connection

# %%
load_ml_config()
# Out:
# Configuration loaded successfully.

# %%
# Test the mlflow connection
client = MlflowClient()

test_server_connection(client)
# Out:
# MLflow connection successful!
# Found 1 experiment(s)
